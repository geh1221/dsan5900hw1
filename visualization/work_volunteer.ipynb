# %%
import pandas as pd

data = pd.read_csv("../data/cleaned_data/data_cleaned.csv")
data = data.drop(columns = ["Unnamed: 0"])
data.head(1000)
# Out:
#     Decision       State   GPA  WorkExp  TestScore  WritingScore  Gender  \
# 0      Admit  California  3.90      6.7      962.0         100.0       1
# 1      Admit     Florida  3.80      1.4      969.0          97.0       1
# 2      Admit    Colorado  3.60      0.9      969.0          97.0       0
# 3      Admit  California  3.88      1.5      967.0          95.0       1
# 4      Admit  California  3.70      1.2      969.0          94.0       1
# ..       ...         ...   ...      ...        ...           ...     ...
# 74  Waitlist     Vermont  3.53      3.3      862.0          85.0       1
# 75  Waitlist     Florida  3.52      0.7      868.0          81.0       0
# 76  Waitlist     Florida  3.51      3.4      865.0          88.0       1
# 77  Waitlist  California  3.47      2.2      867.0          77.0       1
# 78  Waitlist     Florida  3.46      1.9      869.0          89.0       1
#
#     VolunteerLevel
# 0                0
# 1                4
# 2                2
# ...

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

sns.lmplot(data = data, x = "GPA", y = "WorkExp")

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

sns.lmplot(data = data, x = "GPA", y = "VolunteerLevel")

# %%
sns.catplot(data = data, kind = "count", x = "VolunteerLevel")

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x="State", y="WorkExp")
plt.xticks(rotation=45)
plt.title("Work Experience Distribution by State")
plt.show()

# %%
sns.violinplot(data=data, x="Decision", y="WorkExp")
plt.title("Work Experience by Admission Decision")
plt.show()

# %%
data["Decision_Num"] = data["Decision"].map({"Admit": 1, "Decline": -1, "Waitlist": 0})

corr = data.corr(numeric_only=True)
mask = np.triu(np.ones_like(corr, dtype=bool), k=1)

plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f", mask = mask)
plt.title("Correlation Matrix")
plt.show()
